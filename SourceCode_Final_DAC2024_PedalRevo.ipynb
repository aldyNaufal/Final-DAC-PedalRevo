# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
data = pd.read_csv("Data_DAC2024.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job titles         4706 non-null   object
#  1   AI Impact          4706 non-null   float64
#  2   Tasks              4706 non-null   int64
#  3   AI models          4706 non-null   int64
#  4   AI_Workload_Ratio  4706 non-null   float64
#  5   Domain             4706 non-null   object
#  6   Country            4706 non-null   object
#  7   Salary             4706 non-null   float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 294.3+ KB

# %%
high_impact = data[data["AI Impact"] >= 0.6]

# %%
medium_impact = data[(data["AI Impact"] >= 0.3) & (data["AI Impact"] < 0.6)]

# %%
less_impact = data[data["AI Impact"] < 0.3]

# %%
print("Domain dan Jumlah Job Title per Domain High Impact AI")
for dom in high_impact["Domain"].unique():
    print(dom, len(high_impact[high_impact["Domain"] == dom]["Job titles"].unique()))
# Out:
# Domain dan Jumlah Job Title per Domain High Impact AI
# Hospitality 48
# Construction 48
# Communication & PR 48
# Sales & Marketing 48
# Law Enforcement 48
# Medical & Healthcare 48
# Administrative & Clerical 48
# Supply Chain & Logistics 48
# Leadership & Strategy 48
# Data & IT 48

# %%
print("Domain dan Jumlah Job Title per Domain Medium Impact AI")
for dom in medium_impact["Domain"].unique():
    print(dom, len(medium_impact[medium_impact["Domain"] == dom]["Job titles"].unique()))
# Out:
# Domain dan Jumlah Job Title per Domain Medium Impact AI
# Sales & Marketing 179
# Medical & Healthcare 179
# Communication & PR 179
# Construction 179
# Supply Chain & Logistics 179
# Administrative & Clerical 179
# Data & IT 179
# Law Enforcement 179
# Leadership & Strategy 179
# Hospitality 178

# %%
print("Domain dan Jumlah Job Title per Domain Less Impact AI")
for dom in less_impact["Domain"].unique():
    print(dom, len(less_impact[less_impact["Domain"] == dom]["Job titles"].unique()))
# Out:
# Domain dan Jumlah Job Title per Domain Less Impact AI
# Supply Chain & Logistics 244
# Law Enforcement 243
# Leadership & Strategy 244
# Medical & Healthcare 244
# Communication & PR 244
# Sales & Marketing 243
# Administrative & Clerical 244
# Construction 243
# Hospitality 244
# Data & IT 244

# %%
for col in high_impact.columns:
    if high_impact[col].dtype == "object":
        print(col, high_impact[col].unique(), len(high_impact[col].unique()))
# Out:
# Job titles ['General Clerk' 'Bricklayer' 'Contact Tracing' 'Phone Sales'
#  'Credit Specialist' 'Database Engineer' 'Tax Analyst'
#  'Embedded Systems Engineer' 'Bookkeeping' 'Engineering Project Manager'
#  'Warranty Clerk' 'Procurement Assistant' 'Warehouse Associate'
#  'Purchasing Coordinator' 'Public Safety Dispatcher' 'Energy Analyst'
#  'Electrical Drafter' 'Merchandising Coordinator' 'Import Coordinator'
#  'Cashier' 'Performance Analyst' 'Windows Administrator' 'Data Technician'
#  'Computer Scientist' 'Market Research Interviewer'
#  'Industrial Organizational Psychologist' 'Financial Examiner'
#  'Java Web Developer' 'Skip Tracer' 'Administrative Officer'
#  'Front End Web Developer' 'Procurement Clerk' 'J2Ee Developer'
#  'Data Collector' 'Mainframe Programmer' 'Accountant'
#  'Sap Project Manager' 'QA Automation Engineer'
#  'Certified Surgical Technologist' 'Supply Chain Coordinator'
#  'Health Data Analyst' 'Sports Analyst' 'Forensic Chemist'
#  'Front Desk Attendant' 'Database Developer' 'Web Project Manager'
#  'Electrical Technician' 'Infrastructure Project Manager'
#  'Executive Administrative Assistant' 'Trader' 'Collections Specialist'
#  'Finance Officer' 'Network Systems Administrator' 'Game Artist'
#  'Computational Linguist' 'Developer' 'Junior Software Engineer'
#  'Medical Coding Specialist' 'Java Software Developer' 'Ultrasonographer'
#  'Corporate Financial Analyst' 'Medical Claims Processor' 'Mailroom Clerk'
#  'Warehouse Worker' 'Administrative Coordinator' 'Office Clerk'
#  'Executive Secretary' 'Implementation Analyst' 'Administrative Associate'
#  'Healthcare Project Manager' 'Automation Tester' 'Dot Net Developer'
#  'Front Desk Clerk' 'Police Dispatcher' 'General Office Clerk'
#  'Virtual Teacher' 'Dishwasher' 'Intelligence Analyst' 'Survey Researcher'
#  'Chief Executive Officer (CEO)' 'Cleaner' 'Demand Planner'
#  'Medical Office Assistant' 'Automation Test Engineer' 'Seo Specialist'
#  'Database Programmer' 'Logistics Clerk' 'Debt Collector'
#  'Junior Architect' 'Photo Retoucher' 'Data Architect' 'Special Agent'
#  'Ticket Agent' 'Web Search Evaluator' 'Investigative Analyst'
#  'Database Architect' 'Equity Analyst' 'Budget Analyst' 'Order Filler'
#  'Vascular Sonographer' 'Software Project Manager' 'Mail Sorter'
#  'Quantitative Analyst' 'Android Developer' 'Assistant Branch Manager'
#  'Word Processor' 'Lactation Consultant' '3D Modeler'
#  'Data Entry Specialist' 'Grocer' 'Assembly Worker' 'Commercial Analyst'
#  'Direct Support Professional' 'Mortgage Loan Closer' 'Customer Assistant'
#  'Sas Developer' 'Digital Project Manager' 'Hospital Housekeeping'
#  'Technical Project Manager' 'General Worker' 'Clinical Data Analyst'
#  'Desk Receptionist' 'Rpg Programmer' 'Requirements Analyst' 'Cad Drafter'
#  'Drafter' 'Telemarketer' 'Compliance Officer' 'Allocation Analyst'
#  'Healthcare Data Analyst' 'Compositor' 'Freelance'
#  'Associate Software Engineer' 'Forensic Accountant'
#  'Administrative Director' 'Finance Analyst' 'Supply Coordinator'
#  'Java Software Engineer' 'Mystery Shopper' 'Intelligence'
#  'It Project Manager' 'Database Specialist' 'Front Office Clerk'
#  'Full Stack Developer' 'Bakery Manager' 'Ticket Taker'
#  'Collection Specialist' 'Sql Dba' '911 Operator' 'Entry Level Developer'
#  'Collection Representative' 'Sap Developer' 'Security Consultant'
#  'Technical Marketing Engineer' 'Front Desk Coordinator'
#  'Security Dispatcher' 'Statistical Analyst' 'Radio Operator'
#  'Structural Designer' 'Cloud Architect' 'Sql Data Analyst'
#  'Housekeeping Attendant' 'Equity Research Analyst' 'Import Specialist'
#  'Clerical Assistant' 'Cloud Engineer' 'Appointment Scheduler'
#  'Sql Server Developer' 'Post Office' 'Supply Technician'
#  'Assembly Operator' 'Usher' 'Firmware Engineer' 'Manual Qa Tester'
#  'Administration' 'Drupal Developer' 'Database Analyst'
#  'Forensic Scientist' 'Shipping Clerk' 'Creative Project Manager'
#  'Senior Systems Engineer' 'Administrative Assistant' 'Order Processor'
#  'Clerk Typist' 'Mortgage Closer' 'Postal Clerk' 'Credit Manager' 'Typist'
#  'Director Of Operations' 'Timekeeper' 'General Laborer' 'Ui Developer'
#  'Chief Of Staff' 'Analog Design Engineer' 'Abap Developer'
#  'Emergency Dispatcher' 'Financial Auditor' 'Salesforce Business Analyst'
#  'Supply Clerk' 'Truss Designer' 'Vascular Technologist'
#  'Clinical Informatics Specialist' 'Teradata Developer' 'Epic Trainer'
#  'Ux Developer' 'Cad Operator' 'Environmental Engineer'
#  'Ultrasound Technician' 'Game Programmer' 'Credit Risk Analyst'
#  'Full Charge Bookkeeper' 'Junior Developer'
#  'Chief Communications Officer' 'Medical Collector'
#  'Sales Operations Analyst' 'Freelancer' 'Financial Analyst'
#  'Application Developer' 'Financial Data Analyst' 'Surgical Assistant'
#  'Communications Manager' 'Qa Software Tester' 'Mail Processing'
#  'Inpatient Coder' 'Infrastructure Architect' 'Assistant' 'Data Clerk'
#  'Electronic Assembler' 'Java Engineer' 'Java' 'Front End Engineer'
#  'Vmware Administrator' 'Epic Analyst' 'Bookkeeper'
#  'Software Product Manager' 'Pega Developer' 'Technical Product Manager'
#  'Executive Producer' 'Curriculum Designer' 'Arabic Linguist'
#  'Sql Database Administrator' 'Business Banking Relationship Manager'
#  'Flooring Installer' 'Crm Analyst' 'Front Desk Receptionist'
#  'Data Scientist' 'Data Entry' 'Document Processor' '911 Dispatcher'
#  'Informatica Developer' 'Database Administrator' 'Distribution Clerk'
#  'Front Desk' 'Accessioner' 'Unix Administrator' 'Data Entry Operator'
#  'Business Operations Manager' 'Tax Accountant' 'Pl Sql Developer'
#  'Survey Technician' 'Master Control Operator' 'Tableau Developer'
#  'Quantitative Developer' 'Bank Teller' 'Assignment Editor'
#  'Biztalk Developer' 'Oracle Developer' 'Assembly Line Worker'
#  'Etl Developer' 'Sql Analyst' 'Carpet Cleaner' 'Admin' 'Processor'
#  'Chief Learning Officer' 'Grant Accountant' 'Process Server'
#  'Database Designer' 'Therapist' 'Technology Project Manager'
#  'Life Insurance Agent' 'Deputy Director' 'Radiology Assistant' 'Pressman'
#  'Insurance Sales Representative' 'Surgery Scheduler' 'Claims Auditor'
#  'Registered Medical Assistant' 'Project Manager' 'Administrative Clerk'
#  'Statistical Programmer' 'Radiology Technologist' 'Derivatives Analyst'
#  'Clinical Trial Assistant' 'Registration Specialist' 'Net Developer'
#  'Telesales Representative' 'Quantitative Research Analyst'
#  '.Net Developer' 'Military Analyst' 'Information Analyst'
#  'Asp.Net Developer' 'Shipping' 'Associate' 'Forklift'
#  'Junior Java Developer' 'Order Clerk' 'Backend Developer' 'Data Analyst'
#  'Exchange Engineer' 'Mortgage Loan Processor' 'Biotechnology'
#  'Design Engineer' 'Medical Scribe' 'Help Desk' 'Collection Agent'
#  'Unit Secretary' 'Purchasing Assistant' 'Accounting Clerk'
#  'Sql Developer' 'Data Entry Clerk' 'Sql Server Dba' 'Security Technician'
#  'Fx Artist' 'Hadoop Developer' 'Medical Biller' 'Clinical Analyst'
#  'Sonographer' 'Executive Personal Assistant' 'Payment Processor'
#  'Java Programmer' 'Coldfusion Developer' 'Automation Engineer'
#  'Gis Developer' 'Assistant Director' 'Payroll Processor'
#  'Safety Coordinator' 'Banquet Manager' 'Game Developer'
#  'Receiving Associate' 'Mail Handler' 'Seo Consultant' 'Autocad Drafter'
#  'Scribe' 'Executive Assistant' 'Actuary' 'Operations Research Analyst'
#  'Records Clerk' 'Sql Database Developer' 'Financial Engineer'
#  'Stenographer' 'Mail Clerk' 'Chief Strategy Officer' 'Polygraph Examiner'
#  'Logistics Coordinator' 'Fingerprint Technician' 'Appointment Setter'
#  'C# Developer' 'Credit Analyst' 'Seo Manager' 'Accounts Payable'
#  'Business Relationship Manager' 'Compliance Auditor'
#  'Administrative Specialist' 'Front Desk Agent' 'Street Sweeper'
#  'Desk Clerk' 'Custodian' 'Purchasing Clerk' 'Finance Specialist'
#  'Windows System Administrator' 'Director Of Nursing'
#  'Environmental Analyst' 'Tax Examiner' 'Robotics Engineer'
#  'Cobol Developer' 'Contract Specialist' 'Unix System Administrator'
#  'Caller' 'Printing Press Operator' 'Operations Clerk' 'Space Planner'
#  'Receiver' 'Loan Closer' 'Chief Security Officer'
#  'Corporate Receptionist' 'General Labor' 'Pricing Specialist' 'Ecommerce'
#  'Janitor' 'Regulatory Analyst' 'Assistant Administrator'
#  'Branch Office Administrator' 'X Ray Technician' 'Product Manager'
#  'Javascript Developer' 'File Clerk' 'Business Manager'
#  'Ultrasound Technologist' 'Medical Billing Specialist'
#  'Healthcare Business Analyst' 'Press Operator'
#  'Registered Dental Assistant' 'Business Management Consultant'
#  'Registration Clerk' 'Credit Officer' 'Safety Consultant'
#  'Project Consultant' 'Shipping Coordinator' 'Front End Developer'
#  'Medical Coder' 'Chief Of Police' 'Financial Specialist'
#  'Software Engineer' 'Information Specialist' 'Vba Developer'
#  'Coding Specialist' 'Home Inspector' 'Transcriber' 'Title Clerk'
#  'Systems Administrator' 'Web Content Manager' 'Radiologic Technologist'
#  'Solar Sales' 'Report Analyst' 'Cad Technician' 'Technology'
#  'Manual Tester' 'Vascular Technician' 'Forensic Examiner'
#  'Insurance Sales' 'Front Office Receptionist' 'Meter Reader'
#  'Line Operator' 'Cost Controller' 'Autopsy Assistant' 'Ios Developer'
#  'Fund Accountant' 'Delivery Driver' 'Armored Truck Driver'
#  'Game Designer' 'Data Modeler' 'Customs Broker' 'Gas Station Attendant'
#  'Information Assurance' 'Correctional Officer' 'Commission Analyst'
#  'Embryologist' 'Advertising Manager' 'Receiving Clerk' 'C Developer'
#  'Compliance Analyst' 'Sales Associate' 'Office Cleaner' 'Urban Planner'
#  'Oracle Database Developer' 'Systems Analyst'
#  'Certified Professional Coder' 'Loan Underwriter' 'Development Manager'
#  'Equity Research Associate' 'Distribution Manager' 'Report Developer'
#  'Tax Preparer' 'Web Content Editor' 'Treasury Accountant'
#  'Purchasing Buyer' 'Risk Management Analyst' 'Cost Accountant'
#  'Procurement Agent' 'Auditor' 'Erp Project Manager' 'Biomedical Engineer'
#  'Perl Developer' 'Medical Transcriptionist' 'Revenue Cycle Analyst'
#  'Credit Controller' 'Sql Programmer' 'Java Developer'
#  'Administrative Secretary' 'Curriculum Specialist'] 480
# Domain ['Hospitality' 'Construction' 'Communication & PR' 'Sales & Marketing'
#  'Law Enforcement' 'Medical & Healthcare' 'Administrative & Clerical'
#  'Supply Chain & Logistics' 'Leadership & Strategy' 'Data & IT'] 10
# Country ['Singapore'] 1

# %%
for col in medium_impact.columns:
    if medium_impact[col].dtype == "object":
        print(col, medium_impact[col].unique(), len(medium_impact[col].unique()))
# Out:
# Job titles ['Geoscientist' 'Industrial Maintenance Technician'
#  'Employment Specialist' ... 'Agricultural Engineer' 'Media Coordinator'
#  'Network Systems Engineer'] 1789
# Domain ['Sales & Marketing' 'Medical & Healthcare' 'Communication & PR'
#  'Construction' 'Supply Chain & Logistics' 'Administrative & Clerical'
#  'Data & IT' 'Law Enforcement' 'Leadership & Strategy' 'Hospitality'] 10
# Country ['Philippines' 'Malaysia' 'Thailand' 'Indonesia' 'Singapore'] 5

# %%
for col in less_impact.columns:
    if less_impact[col].dtype == "object":
        print(col, less_impact[col].unique(), len(less_impact[col].unique()))
# Out:
# Job titles ['Adjunct Instructor' 'Technical Analyst' 'Design Manager' ...
#  'Utility Engineer' 'Quality Control' 'Author'] 2437
# Domain ['Supply Chain & Logistics' 'Law Enforcement' 'Leadership & Strategy'
#  'Medical & Healthcare' 'Communication & PR' 'Sales & Marketing'
#  'Administrative & Clerical' 'Construction' 'Hospitality' 'Data & IT'] 10
# Country ['Cambodia' 'Vietnam' 'Myanmar' 'Laos' 'Philippines'] 5

# %%
numeric = []
for col in data.columns:
    if data[col].dtype != "object":
        numeric.append(col)

# %%
data_numerik = data[numeric]

# %%
data_numerik_corr = data_numerik.corr()

# %%
sns.heatmap(data_numerik_corr,annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 8))
sns.pairplot(data_numerik)
plt.suptitle('Pairplot of Features')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.title("Negara")
sns.countplot(data=data,x="Country")
# Out:
# <Axes: title={'center': 'Negara'}, xlabel='Country', ylabel='count'>

# %%
data['AI Impact Binned'] = (data['AI Impact'] // 0.1) * 0.1

salary_mean = data.groupby('AI Impact Binned')['Salary'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='AI Impact Binned', y='Salary', data=salary_mean, marker="o")
plt.title('AI Impact VS Salary')
plt.xlabel('Korelasi Impact dan Salary')
plt.ylabel('Average Salary')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job titles         4706 non-null   object
#  1   AI Impact          4706 non-null   float64
#  2   Tasks              4706 non-null   int64
#  3   AI models          4706 non-null   int64
#  4   AI_Workload_Ratio  4706 non-null   float64
#  5   Domain             4706 non-null   object
#  6   Country            4706 non-null   object
#  7   Salary             4706 non-null   float64
#  8   AI Impact Binned   4706 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 331.0+ KB

# %%
data["Domain"].unique()
# Out:
# array(['Hospitality', 'Supply Chain & Logistics', 'Law Enforcement',
#        'Sales & Marketing', 'Construction', 'Medical & Healthcare',
#        'Leadership & Strategy', 'Communication & PR',
#        'Administrative & Clerical', 'Data & IT'], dtype=object)

# %%
# fitur yang digunakan selain domain, workload ratio, dan Job titles karena relevansinya kurang

data = data.drop(columns=["Job titles", "Domain", "AI_Workload_Ratio"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AI Impact         4706 non-null   float64
#  1   Tasks             4706 non-null   int64
#  2   AI models         4706 non-null   int64
#  3   Country           4706 non-null   object
#  4   Salary            4706 non-null   float64
#  5   AI Impact Binned  4706 non-null   float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 220.7+ KB

# %%
data.head()
# Out:
#    AI Impact  Tasks  AI models      Country  Salary  AI Impact Binned
# 0       0.90    242       1903    Singapore  260.00               0.8
# 1       0.05   1174       4677     Cambodia  580.00               0.0
# 2       0.25    836       2289      Vietnam  556.25               0.2
# 3       0.30    127       1382  Philippines  550.00               0.2
# 4       0.85      3         30    Singapore  290.00               0.8

# %%
encoder = LabelEncoder()
encoder.fit(['Cambodia','Vietnam','Myanmar','Laos','Philippines','Malaysia','Thailand','Indonesia','Singapore'])
# Out:
# LabelEncoder()

# %%
data["Country"] = encoder.transform(data["Country"])

# %%
data.head()
# Out:
#    AI Impact  Tasks  AI models  Country  Salary  AI Impact Binned
# 0       0.90    242       1903        6  260.00               0.8
# 1       0.05   1174       4677        0  580.00               0.0
# 2       0.25    836       2289        8  556.25               0.2
# 3       0.30    127       1382        5  550.00               0.2
# 4       0.85      3         30        6  290.00               0.8

# %%
x = data.drop(columns="Salary")
y = data["Salary"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
regr = GradientBoostingRegressor()
rdf = RandomForestRegressor()
dtr = DecisionTreeRegressor()
xgr = XGBRegressor(objective='reg:squarederror')

models = [regr, rdf, dtr, xgr]
model_names = ['Gradient Boosting', 'Random Forest', 'Decision Tree', 'XGBoost']

# %%
r2_scores = []
rmse_values = []

for model in models:

    model.fit(x_train, y_train)


    y_pred = model.predict(x_test)
    print(f'Model: {model.__class__.__name__}')
    print(f'R2 Score: {r2_score(y_test, y_pred)}')
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')


    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)


    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse_values.append(rmse)
# Out:
# Model: GradientBoostingRegressor
# R2 Score: 0.9997144393856432
# RMSE: 0.894994025705226
# Model: RandomForestRegressor
# R2 Score: 0.9997886838051789
# RMSE: 0.7699054135455827
# Model: DecisionTreeRegressor
# R2 Score: 0.9996888204743976
# RMSE: 0.9342787901635513
# Model: XGBRegressor
# R2 Score: 0.9998225270189612
# RMSE: 0.7055651225343595

# %%
plt.figure(figsize=(10, 6))
plt.bar(model_names, r2_scores, color='lightblue')
plt.title('R² Score Comparison')
plt.xlabel('Model')
plt.ylabel('R² Score')
plt.ylim([0, 1])
plt.yticks(np.arange(0, 1.01, 0.1))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(model_names, rmse_values, color='lightcoral')
plt.title('RMSE Comparison')
plt.xlabel('Model')
plt.ylabel('RMSE')
plt.ylim([0, max(rmse_values) + 0.1])
plt.yticks(np.arange(0, max(rmse_values) + 0.1, 0.1))
plt.tight_layout()
plt.show()
